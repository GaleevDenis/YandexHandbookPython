# %%
class Car:

    def __init__(self, color, consumption, tank_volume, mileage=0):
        self.color = color
        self.consumption = consumption
        self.tank_volume = tank_volume
        self.reserve = tank_volume
        self.mileage = mileage
        self.engine_on = False

    def start_engine(self):
        if not self.engine_on and self.reserve > 0:
            self.engine_on = True
            return "Двигатель запущен."
        return "Двигатель уже был запущен."

    def stop_engine(self):
        if self.engine_on:
            self.engine_on = False
            return "Двигатель остановлен."
        return "Двигатель уже был остановлен."

    def drive(self, distance):
        if not self.engine_on:
            return "Двигатель не запущен."
        if self.reserve / self.consumption * 100 < distance:
            return "Малый запас топлива."
        self.mileage += distance
        self.reserve -= distance / 100 * self.consumption
        return f"Проехали {distance} км. Остаток топлива: {self.reserve} л."

    def refuel(self):
        self.reserve = self.tank_volume

    def get_mileage(self):
        return self.mileage

    def get_reserve(self):
        return self.reserve


car_1 = Car(color="black", consumption=10, tank_volume=55)
print(car_1.start_engine())
print(car_1.drive(100))
print(car_1.drive(100))
print(car_1.drive(100))
print(car_1.drive(300))
print(f"Пробег {car_1.get_mileage()} км.")
print(f"Запас топлива {car_1.get_reserve()} л.")
print(car_1.stop_engine())
print(car_1.drive(100))
# Out:
# Двигатель запущен.
# Проехали 100 км. Остаток топлива: 45.0 л.
# Проехали 100 км. Остаток топлива: 35.0 л.
# Проехали 100 км. Остаток топлива: 25.0 л.
# Малый запас топлива.
# Пробег 300 км.
# Запас топлива 25.0 л.
# Двигатель остановлен.
# Двигатель не запущен.

# %%
class Car:

    def __init__(self, color, consumption, tank_volume, mileage=0):
        self.color = color
        self.consumption = consumption
        self.tank_volume = tank_volume
        self.reserve = tank_volume
        self.mileage = mileage
        self.engine_on = False

    def start_engine(self):
        if not self.engine_on and self.reserve > 0:
            self.engine_on = True
            return "Двигатель запущен."
        return "Двигатель уже был запущен."

    def stop_engine(self):
        if self.engine_on:
            self.engine_on = False
            return "Двигатель остановлен."
        return "Двигатель уже был остановлен."

    def drive(self, distance):
        if not self.engine_on:
            return "Двигатель не запущен."
        if self.reserve / self.consumption * 100 < distance:
            return "Малый запас топлива."
        self.mileage += distance
        self.reserve -= distance / 100 * self.consumption
        return f"Проехали {distance} км. Остаток топлива: {self.reserve} л."

    def refuel(self):
        self.reserve = self.tank_volume

    def get_mileage(self):
        return self.mileage

    def get_reserve(self):
        return self.reserve

    def get_consumption(self):
        return self.consumption


class ElectricCar:

    def __init__(self, color, consumption, bat_capacity, mileage=0):
        self.color = color
        self.consumption = consumption
        self.bat_capacity = bat_capacity
        self.reserve = bat_capacity
        self.mileage = mileage
        self.engine_on = False

    def start_engine(self):
        if not self.engine_on and self.reserve > 0:
            self.engine_on = True
            return "Двигатель запущен."
        return "Двигатель уже был запущен."

    def stop_engine(self):
        if self.engine_on:
            self.engine_on = False
            return "Двигатель остановлен."
        return "Двигатель уже был остановлен."

    def drive(self, distance):
        if not self.engine_on:
            return "Двигатель не запущен."
        if self.reserve / self.consumption * 100 < distance:
            return "Малый заряд батареи."
        self.mileage += distance
        self.reserve -= distance / 100 * self.consumption
        return f"Проехали {distance} км. Остаток заряда: {self.reserve} кВт*ч."

    def recharge(self):
        self.reserve = self.bat_capacity

    def get_mileage(self):
        return self.mileage

    def get_reserve(self):
        return self.reserve

    def get_consumption(self):
        return self.consumption


def range_reserve(car):
    return car.get_reserve() / car.get_consumption() * 100


car_1 = Car(color="black", consumption=10, tank_volume=55)
car_2 = ElectricCar(color="white", consumption=15, bat_capacity=90)
print(f"Запас хода: {range_reserve(car_1)} км.")
print(f"Запас хода: {range_reserve(car_2)} км.")
# Out:
# Запас хода: 550.0 км.
# Запас хода: 600.0 км.

# %%
# A Решена

class Point:
    
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
point = Point(3, 5)
print(point.x, point.y)
# Out:
# 3 5

# %%
# B Решена

class Point:
    
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def move(self, move_x, move_y):
        self.x = self.x + move_x
        self.y = self.y + move_y
        return self.x, self.y
    
    def length(self, tochka):
        if self.x >= 0 and tochka.x >= 0:
            x_min = min(self.x, tochka.x)
            x_max = max(self.x, tochka.x)
            x = x_max - x_min
        elif self.x <= 0 and tochka.x <= 0:
            x_min = min(abs(self.x), abs(tochka.x))
            x_max = max(abs(self.x), abs(tochka.x))
            x = x_max - x_min
        else:
            x_min = min(self.x, tochka.x)
            x_max = max(self.x, tochka.x)
            x = abs(x_min) + x_max
        if self.y >= 0 and tochka.y >= 0:
            y_min = min(self.y, tochka.y)
            y_max = max(self.y, tochka.y)
            y = y_max - y_min
        elif self.y <= 0 and tochka.y <= 0:
            y_min = min(abs(self.y), abs(tochka.y))
            y_max = max(abs(self.y), abs(tochka.y))
            y = y_max - y_min
        else:
            y_min = min(self.y, tochka.y)
            y_max = max(self.y, tochka.y)
            y = abs(y_min) + y_max
        result = round((x ** 2 + y ** 2) ** 0.5, 2)
        return result
    

first_point = Point(2, -7)
second_point = Point(7, 9)
print(first_point.length(second_point))
print(second_point.length(first_point))
# Out:
# 16.76
# 16.76

# %%
# С решена

class RedButton:
    
    def __init__(self, click_1="Тревога!", count_1=0):
        self.click_1 = click_1
        self.count_1 = count_1
        
    def click(self):
        self.count_1 += 1
        return print(self.click_1)
    
    def count(self):
        return self.count_1


first_button = RedButton()
second_button = RedButton()
for time in range(5):
    if time % 2 == 0:
        second_button.click()
    else:
        first_button.click()
print(first_button.count(), second_button.count())
# Out:
# Тревога
# Тревога
# Тревога
# Тревога
# Тревога
# 2 3

# %%
# D

class Programmer:
    
    def __init__(self, name, dolj, times=0, zp=0, rise_1=0):
        self.name = name
        self.dolj = dolj
        self.times = times
        self.zp = zp
        self.rise_1 = rise_1
        
    def work(self, time):
        self.times += time
        if self.dolj == "Junior":
            self.zp += time * 10
        elif self.dolj == "Middle":
            self.zp += time * 15
        elif self.dolj == "Senior":
            self.zp += time * (20 + self.rise_1)
                               
    def rise(self):
        if self.dolj == "Junior":
            self.dolj = "Middle"
        elif self.dolj == "Middle":
            self.dolj = "Senior"
        else:
            self.rise_1 += 1
        
    def info(self):
        return f"{self.name} {self.times}ч. {self.zp}тгр."
    
    
programmer = Programmer('Васильев Иван', 'Junior')
programmer.work(750)
print(programmer.info())
programmer.rise()
programmer.work(500)
print(programmer.info())
programmer.rise()
programmer.work(250)
print(programmer.info())
programmer.rise()
programmer.work(250)
print(programmer.info())
# Out:
# Васильев Иван 750ч. 7500тгр.
# Васильев Иван 1250ч. 15000тгр.
# Васильев Иван 1500ч. 20000тгр.
# Васильев Иван 1750ч. 25250тгр.

# %%
# E Решена

class Rectangle:
    
    def __init__(self, ugol_1, ugol_2):
        self.x_1 = ugol_1[0]
        self.x_2 = ugol_2[0]
        self.y_1 = ugol_1[1]
        self.y_2 = ugol_2[1]
        
    def perimeter(self):
        if self.x_1 >= 0 and self.x_2 >= 0:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = x_max - x_min
        elif self.x_1 <= 0 and self.x_2 <= 0:
            x_min = min(abs(self.x_1), abs(self.x_2))
            x_max = max(abs(self.x_1), abs(self.x_2))
            x = x_max - x_min
        else:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = abs(x_min) + x_max
        if self.y_1 >= 0 and self.y_2 >= 0:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = y_max - y_min
        elif self.y_1 <= 0 and self.y_2 <= 0:
            y_min = min(abs(self.y_1), abs(self.y_2))
            y_max = max(abs(self.y_1), abs(self.y_2))
            y = y_max - y_min
        else:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = abs(y_min) + y_max
        result = round((x + y) * 2, 2)
        return result
    
    def area(self):
        if self.x_1 >= 0 and self.x_2 >= 0:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = x_max - x_min
        elif self.x_1 <= 0 and self.x_2 <= 0:
            x_min = min(abs(self.x_1), abs(self.x_2))
            x_max = max(abs(self.x_1), abs(self.x_2))
            x = x_max - x_min
        else:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = abs(x_min) + x_max
        if self.y_1 >= 0 and self.y_2 >= 0:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = y_max - y_min
        elif self.y_1 <= 0 and self.y_2 <= 0:
            y_min = min(abs(self.y_1), abs(self.y_2))
            y_max = max(abs(self.y_1), abs(self.y_2))
            y = y_max - y_min
        else:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = abs(y_min) + y_max
        return round(x * y, 2)
    
    
rect = Rectangle((3.2, -4.3), (7.52, 3.14))
print(rect.perimeter())
        
rect = Rectangle((7.52, -4.3), (3.2, 3.14))
print(rect.area())
# Out:
# 23.52
# 32.14

# %%
# F Решена!

class Rectangle:
    
    def __init__(self, ugol_1, ugol_2):
        self.x_1 = ugol_1[0]
        self.x_2 = ugol_2[0]
        self.y_1 = ugol_1[1]
        self.y_2 = ugol_2[1]
        
    def perimeter(self):
        if self.x_1 >= 0 and self.x_2 >= 0:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = x_max - x_min
        elif self.x_1 <= 0 and self.x_2 <= 0:
            x_min = min(abs(self.x_1), abs(self.x_2))
            x_max = max(abs(self.x_1), abs(self.x_2))
            x = x_max - x_min
        else:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = abs(x_min) + x_max
        if self.y_1 >= 0 and self.y_2 >= 0:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = y_max - y_min
        elif self.y_1 <= 0 and self.y_2 <= 0:
            y_min = min(abs(self.y_1), abs(self.y_2))
            y_max = max(abs(self.y_1), abs(self.y_2))
            y = y_max - y_min
        else:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = abs(y_min) + y_max
        result = round((x + y) * 2, 2)
        return result
    
    def area(self):
        if self.x_1 >= 0 and self.x_2 >= 0:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = x_max - x_min
        elif self.x_1 <= 0 and self.x_2 <= 0:
            x_min = min(abs(self.x_1), abs(self.x_2))
            x_max = max(abs(self.x_1), abs(self.x_2))
            x = x_max - x_min
        else:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = abs(x_min) + x_max
        if self.y_1 >= 0 and self.y_2 >= 0:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = y_max - y_min
        elif self.y_1 <= 0 and self.y_2 <= 0:
            y_min = min(abs(self.y_1), abs(self.y_2))
            y_max = max(abs(self.y_1), abs(self.y_2))
            y = y_max - y_min
        else:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = abs(y_min) + y_max
        return round(x * y, 2)
    
    def get_pos(self):
        x = min(self.x_1, self.x_2)
        y = max(self.y_1, self.y_2)
        return (x, y)
    
    def get_size(self):
        if self.x_1 >= 0 and self.x_2 >= 0:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = x_max - x_min
        elif self.x_1 <= 0 and self.x_2 <= 0:
            x_min = min(abs(self.x_1), abs(self.x_2))
            x_max = max(abs(self.x_1), abs(self.x_2))
            x = x_max - x_min
        else:
            x_min = min(self.x_1, self.x_2)
            x_max = max(self.x_1, self.x_2)
            x = abs(x_min) + x_max
        if self.y_1 >= 0 and self.y_2 >= 0:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = y_max - y_min
        elif self.y_1 <= 0 and self.y_2 <= 0:
            y_min = min(abs(self.y_1), abs(self.y_2))
            y_max = max(abs(self.y_1), abs(self.y_2))
            y = y_max - y_min
        else:
            y_min = min(self.y_1, self.y_2)
            y_max = max(self.y_1, self.y_2)
            y = abs(y_min) + y_max
        return (round(x, 2), round(y, 2))
    
    def move(self, *new_znach):
        self.x_1 = round(self.x_1 + new_znach[0], 2)
        self.x_2 = round(self.x_2 + new_znach[0], 2)
        self.y_1 = round(self.y_1 + new_znach[1], 2)
        self.y_2 = round(self.y_2 + new_znach[1], 2)
    
    def resize(self, width, height):
        if self.x_1 < self.x_2:
            self.x_2 = self.x_1 + width
        else:
            self.x_1 = self.x_2 + width
        if self.y_1 < self.y_2:
            self.y_1 = self.y_2 - height
        else:
            self.y_2 = self.y_1 - height
            
    def turn(self): # найти координату центра прямоугольник потом от этой точки строить перевернутый прямоугольник учитывать - + знаки у точек
        pass

rect = Rectangle((3.14, 2.71), (-3.14, -2.71))
print(rect.get_pos(), rect.get_size(), sep='\n')
rect.turn()
print(rect.get_pos(), rect.get_size(), sep='\n')
# Out:
# (-3.14, 2.71)
# (6.28, 5.42)
# (-3.14, 2.71)
# (6.28, 5.42)

# %%
# С начала начал

class car:
    def __init__(self, color, consumption, tank_volume, mileage=0):
        self.color = color
        self.consumption = consumption
        self.tank_volume = tank_volume
        self.reserve = tank_volume
        self.mileage = mileage
        self.engine_on = False

    def start_engine(self):
        if not self.engine_on and self.reserve > 0:
            self.engine_on = True
            return "Двигатель запущен"
        return "Двигатель уже был запущен"

    def stop_engine(self):
        if self.engine_on:
            self.engine_on = False
            return "Двигатель остановлен"
        return "Двигатель уже был остановлен"
    
    def drive(self, distance):
        if not self.engine_on:
            return "Двигатель не запущен"
        if self.reserve / self.consumption * 100 < distance:
            return "Малый запас топлива"
        self.mileage += distance
        self.reserve -= distance / 100 * self.consumption
        return f"Проехали {distance} км. Остаток топлива: {self.reserve} л."
    
    def refuel(self):
        self.reserve = self.tank_volume

    def get_mileage(self):
        return self.mileage

    def get_reserve(self):
        return self.reserve

car_1 = car(color="black", consumption=10, tank_volume=55)
print(car_1.start_engine())
print(car_1.drive(100))
print(car_1.drive(100))
print(car_1.drive(100))
print(car_1.drive(300))
print(f"Пробег {car_1.get_mileage()} км.")
print(f"Запас топлива {car_1.get_reserve()} л.")
print(car_1.stop_engine())
print(car_1.drive(100))
# Out:
# Двигатель запущен
# Проехали 100 км. Остаток топлива: 45.0 л.
# Проехали 100 км. Остаток топлива: 35.0 л.
# Проехали 100 км. Остаток топлива: 25.0 л.
# Малый запас топлива
# Пробег 300 км.
# Запас топлива 25.0 л.
# Двигатель остановлен
# Двигатель не запущен

# %%
# A Решена

class Point:
    
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    
    
point = Point(3, 5)
print(point.x, point.y)
# Out:
# 3 5

# %%
# B Решена

class Point:
    
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def move(self, move_x, move_y):
        self.x = self.x + move_x
        self.y = self.y + move_y
        
    def length(self, second):
        range = round((((abs(self.x - second.x)) ** 2) + (abs(self.y - second.y)) ** 2) ** 0.5, 2)
        return range
    
first_point = Point(2, -7)
second_point = Point(7, 9)
print(first_point.length(second_point))
print(second_point.length(first_point))
# Out:
# 16.76
# 16.76

# %%
# С Решена

class RedButton:
    
    def __init__(self, counte=0):
        self.counte = counte
    
    def click(self):
        self.counte += 1
        return print("Тревога!")
    
    def count(self):
        return self.counte
    
first_button = RedButton()
second_button = RedButton()
for time in range(5):
    if time % 2 == 0:
        second_button.click()
    else:
        first_button.click()
print(first_button.count(), second_button.count())
# Out:
# Тревога!
# Тревога!
# Тревога!
# Тревога!
# Тревога!
# 2 3

# %%
# D Решена

class Programmer:
    
    def __init__(self, name, doljnost, time_vsego=0, zarplata=0, oklad=0):
        self.name = name
        self.doljnost = doljnost
        self.time_vsego = time_vsego
        self.zarplata = zarplata
        self.oklad = oklad
        
    def work(self, time):
        self.time_vsego += time
        if self.doljnost == "Junior":
            self.zarplata += 10 * time
        elif self.doljnost == "Middle":
            self.zarplata += 15 * time
        elif self.doljnost == "Senior":
            self.zarplata += (20 + self.oklad) * time
            
    def rise(self):
        if self.doljnost == "Junior":
            self.doljnost = "Middle"
        elif self.doljnost == "Middle":
            self.doljnost = "Senior"
        elif self.doljnost == "Senior":
            self.oklad += 1
            
    def info(self):
        return f"{self.name} {self.time_vsego}ч. {self.zarplata}тгр."
            
        
programmer = Programmer('Васильев Иван', 'Junior')
programmer.work(750)
print(programmer.info())
programmer.rise()
programmer.work(500)
print(programmer.info())
programmer.rise()
programmer.work(250)
print(programmer.info())
programmer.rise()
programmer.work(250)
print(programmer.info())
# Out:
# Васильев Иван 750ч. 7500тгр.
# Васильев Иван 1250ч. 15000тгр.
# Васильев Иван 1500ч. 20000тгр.
# Васильев Иван 1750ч. 25250тгр.

# %%
# E Решена 

class Rectangle:
    
    def __init__(self, ugol_1, ugol_2):
        self.x_1 = ugol_1[0]
        self.x_2 = ugol_2[0]
        self.y_1 = ugol_1[1]
        self.y_2 = ugol_2[1]
        self.range_x = abs(self.x_1 - self.x_2)
        self.range_y = abs(self.y_1 - self.y_2)
        
    def perimeter(self):
        return round((self.range_x + self.range_y) * 2, 2)
    
    def area(self):
        return round((self.range_x * self.range_y), 2)
        
        
rect = Rectangle((7.52, -4.3), (3.2, 3.14))
print(rect.area())
# Out:
# 32.14

# %%
class Car:

    def __init__(self, color, consumption, tank_volume, mileage=0):
        self.color = color
        self.consumption = consumption
        self.tank_volume = tank_volume
        self.reserve = tank_volume
        self.mileage = mileage
        self.engine_on = False

    def start_engine(self):
        if not self.engine_on and self.reserve > 0:
            self.engine_on = True
            return "Двигатель запущен."
        return "Двигатель уже был запущен."

    def stop_engine(self):
        if self.engine_on:
            self.engine_on = False
            return "Двигатель остановлен."
        return "Двигатель уже был остановлен."

    def drive(self, distance):
        if not self.engine_on:
            return "Двигатель не запущен."
        if self.reserve / self.consumption * 100 < distance:
            return "Малый запас топлива."
        self.mileage += distance
        self.reserve -= distance / 100 * self.consumption
        return f"Проехали {distance} км. Остаток топлива: {self.reserve} л."

    def refuel(self):
        self.reserve = self.tank_volume

    def get_mileage(self):
        return self.mileage

    def get_reserve(self):
        return self.reserve

    def get_consumption(self):
        return self.consumption


class ElectricCar:

    def __init__(self, color, consumption, bat_capacity, mileage=0):
        self.color = color
        self.consumption = consumption
        self.bat_capacity = bat_capacity
        self.reserve = bat_capacity
        self.mileage = mileage
        self.engine_on = False

    def start_engine(self):
        if not self.engine_on and self.reserve > 0:
            self.engine_on = True
            return "Двигатель запущен."
        return "Двигатель уже был запущен."

    def stop_engine(self):
        if self.engine_on:
            self.engine_on = False
            return "Двигатель остановлен."
        return "Двигатель уже был остановлен."

    def drive(self, distance):
        if not self.engine_on:
            return "Двигатель не запущен."
        if self.reserve / self.consumption * 100 < distance:
            return "Малый заряд батареи."
        self.mileage += distance
        self.reserve -= distance / 100 * self.consumption
        return f"Проехали {distance} км. Остаток заряда: {self.reserve} кВт*ч."

    def recharge(self):
        self.reserve = self.bat_capacity

    def get_mileage(self):
        return self.mileage

    def get_reserve(self):
        return self.reserve

    def get_consumption(self):
        return self.consumption


def range_reserve(car):
    return car.get_reserve() / car.get_consumption() * 100


car_1 = Car(color="black", consumption=10, tank_volume=55)
car_2 = ElectricCar(color="white", consumption=15, bat_capacity=90)
print(f"Запас хода: {range_reserve(car_1)} км.")
print(f"Запас хода: {range_reserve(car_2)} км.")
# Out:
# Запас хода: 550.0 км.
# Запас хода: 600.0 км.

# %%
# A Решена

class Point:
    
    def __init__(self, x, y):
        self.x = x
        self.y = y

point = Point(3, 5)
print(point.x, point.y)
# Out:
# 16.76
# 16.76

# %%
# B Решена

class Point:
    
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def move(self, move_x, move_y):
        self.x = self.x + move_x
        self.y = self.y + move_y
        
    def length(self, second_point):
        range_x = abs(self.x - second_point.x)
        range_y = abs(self.y - second_point.y)
        range = round((range_x ** 2 + range_y ** 2) ** 0.5, 2)
        return range
    
    
first_point = Point(2, -7)
second_point = Point(7, 9)
print(first_point.length(second_point))
print(second_point.length(first_point))
# Out:
# 16.76
# 16.76

# %%
# C Решена

class RedButton():
    
    def __init__(self):
        self.chislo = 0
        
    def click(self):
        self.chislo += 1
        print("Тревога!") 
        
    def count(self):
        return self.chislo
        
        
first_button = RedButton()
second_button = RedButton()
for time in range(5):
    if time % 2 == 0:
        second_button.click()
    else:
        first_button.click()
print(first_button.count(), second_button.count())
# Out:
# Тревога!
# Тревога!
# Тревога!
# Тревога!
# Тревога!
# 2 3

# %%
# D Решена

class Programmer:
    
    def __init__(self, name, doljnost, otrabotka = 0, zarplata = 0, povishevie = 0):
        self.name = name
        self.doljnost = doljnost
        self.otrabotka = otrabotka
        self.zarplata = zarplata
        self.povishevie = povishevie
        
    def work(self, time):
        self.otrabotka += + time
        if self.doljnost == "Junior":
            self.zarplata += time * 10
        elif self.doljnost == "Middle":
            self.zarplata += time * 15
        elif self.doljnost == "Senior":
            self.zarplata += time * (20 + self.povishevie)  
        
    def rise(self):
        if self.doljnost == "Junior":
            self.doljnost = "Middle"
        elif self.doljnost == "Middle":
            self.doljnost = "Senior"
        elif self.doljnost == "Senior":
            self.povishevie += 1
            
    def info(self):
        return f"{self.name} {self.otrabotka}ч. {self.zarplata}тгр."
        
        
programmer = Programmer('Васильев Иван', 'Junior')
programmer.work(750)
print(programmer.info())
programmer.rise()
programmer.work(500)
print(programmer.info())
programmer.rise()
programmer.work(250)
print(programmer.info())
programmer.rise()
programmer.work(250)
print(programmer.info())
# Out:
# Васильев Иван 750ч. 7500тгр.
# Васильев Иван 1250ч. 15000тгр.
# Васильев Иван 1500ч. 20000тгр.
# Васильев Иван 1750ч. 25250тгр.

# %%
# E Решена

class Rectangle:
    
    def __init__(self, point_1, point_2):
        self.x_1 = point_1[0]
        self.x_2 = point_2[0]
        self.y_1 = point_1[1]
        self.y_2 = point_2[1]
        self.range_x = abs(self.x_1 - self.x_2)
        self.range_y = abs(self.y_1 - self.y_2)  
    
    def perimeter(self):
        return round((self.range_x + self.range_y) * 2, 2)
    
    def area(self):   
        return round((self.range_x * self.range_y), 2)
        
rect = Rectangle((7.52, -4.3), (3.2, 3.14))
print(rect.area())
# Out:
# 32.14

# %%
# F Решена

class Rectangle:
    
    def __init__(self, point_1, point_2):
        self.x_1 = point_1[0]
        self.x_2 = point_2[0]
        self.y_1 = point_1[1]
        self.y_2 = point_2[1]
    
    def perimeter(self):  
        return round((abs(self.x_1 - self.x_2) + abs(self.y_1 - self.y_2)) * 2, 2)
    
    def area(self):    
        return round((abs(self.x_1 - self.x_2) * abs(self.y_1 - self.y_2)), 2)
    
    def get_pos(self):
        return (min(round(self.x_1, 2), round(self.x_2, 2)), max(round(self.y_1, 2), round(self.y_2, 2)))
    
    def get_size(self):
        return (round(abs(self.x_1 - self.x_2), 2), round(abs(self.y_1 - self.y_2), 2))
    
    def move(self, dx, dy):
        self.x_1 += dx
        self.x_2 += dx
        self.y_1 += dy
        self.y_2 += dy
        
    def resize(self, width, height):
        if self.x_1 < self.x_2:
            self.x_2 = width + self.x_1
        else:
            self.x_1 = width + self.x_2
        if self.y_1 > self.y_2:
            self.y_2 = self.y_1 - height
        else:
            self.y_1 = self.y_2 - height
        
rect = Rectangle((7.52, -4.3), (3.2, 3.14))
print(rect.get_pos(), rect.get_size())
rect.resize(23.5, 11.3)
print(rect.get_pos(), rect.get_size())
# Out:
# (3.2, 3.14) (4.32, 7.44)
# (3.2, 3.14) (23.5, 11.3)

# %%
# G ре решена

class Rectangle:
    
    def __init__(self, point_1, point_2):
        self.x_1 = point_1[0]
        self.x_2 = point_2[0]
        self.y_1 = point_1[1]
        self.y_2 = point_2[1]
    
    def perimeter(self):  
        return round((abs(self.x_1 - self.x_2) + abs(self.y_1 - self.y_2)) * 2, 2)
    
    def area(self):    
        return round((abs(self.x_1 - self.x_2) * abs(self.y_1 - self.y_2)), 2)
    
    def get_pos(self):
        return (min(round(self.x_1, 2), round(self.x_2, 2)), max(round(self.y_1, 2), round(self.y_2, 2)))
    
    def get_size(self):
        return (round(abs(self.x_1 - self.x_2), 2), round(abs(self.y_1 - self.y_2), 2))
    
    def move(self, dx, dy):
        self.x_1 += dx
        self.x_2 += dx
        self.y_1 += dy
        self.y_2 += dy
        
    def resize(self, width, height):
        if self.x_1 < self.x_2:
            self.x_2 = width + self.x_1
        else:
            self.x_1 = width + self.x_2
        if self.y_1 > self.y_2:
            self.y_2 = self.y_1 - height
        else:
            self.y_1 = self.y_2 - height
            
    def turn(self):
        centr = (round((self.x_1 + self.x_2) / 2, 2), round((self.y_1 + self.y_2) / 2, 2))
        x_1_new = 0
        x_2_new = 0
        y_1_new = 0
        y_2_new = 0
        if self.x_1 < self.x_2:
            x_1_new = round(centr[0] - (round(abs(self.y_1), 2) + round(abs(self.y_2), 2)) / 2, 2)
            x_2_new = round(centr[0] + (round(abs(self.y_1), 2) + round(abs(self.y_2), 2)) / 2, 2)
        else:
            x_2_new = round(centr[0] - (round(abs(self.y_1), 2) + round(abs(self.y_2), 2)) / 2, 2)
            x_1_new = round(centr[0] + (round(abs(self.y_1), 2) + round(abs(self.y_2), 2)) / 2, 2)
        if self.y_1 < self.y_2:
            y_1_new = round(centr[1] - (round(abs(self.x_1), 2) + round(abs(self.x_2), 2)) / 2, 2)
            y_2_new = round(centr[1] + (round(abs(self.x_1), 2) + round(abs(self.x_2), 2)) / 2, 2)
        else:
            y_2_new = round(centr[1] - (round(abs(self.x_1), 2) + round(abs(self.x_2), 2)) / 2, 2)
            y_1_new = round(centr[1] + (round(abs(self.x_1), 2) + round(abs(self.x_2), 2)) / 2, 2)
        self.x_1 = x_1_new
        self.x_2 = x_2_new
        self.y_1 = y_1_new
        self.y_2 = y_2_new
    
    def scale(self, kratno):
        self.x_1 = round(self.x_1 * kratno, 2)
        self.x_2 = round(self.x_2 * kratno, 2)
        self.y_1 = round(self.y_1 * kratno, 2)
        self.y_2 = round(self.y_2 * kratno, 2)
        
    
rect = Rectangle((3.14, 2.71), (-3.14, -2.71))
print(rect.get_pos(), rect.get_size(), sep='\n')
rect.turn()
print(rect.get_pos(), rect.get_size(), sep='\n')
# Out:
# (-3.14, 2.71)
# (6.28, 5.42)
# (-2.71, 3.14)
# (5.42, 6.28)

# %%
# H

class Checkers:
    
    def __init__(self):
        self.x = []
    
    def move(self, f, t):
        pass
    
    def get_cell(self, p):
        return
    
class cell:
    def __init__(self):
        
checkers = Checkers()

# %%
# I Решена

class Queue:
    
    def __init__(self):
        self.stuck = []
    
    def push(self, item):
        self.stuck.append(item)
        
    def pop(self):
        return self.stuck.pop(0)
    
    def is_empty(self):
        if self.stuck != []:
            return False
        else:
            return True
    
queue = Queue()
for item in ("Hello,", "world!"):
    queue.push(item)
while not queue.is_empty():
    print(queue.pop())
# Out:
# Hello,
# world!

# %%
# J Решена

class Stack:
    
    def __init__(self):
        self.scteck = []
    
    def push(self, item):
        self.scteck.insert(0, item)
        
    def pop(self):
        return self.scteck.pop(0)
    
    def is_empty(self):
        if self.scteck != []:
            return False
        else:
            return True
        
stack = Stack()
for item in ("Hello,", "world!"):
    stack.push(item)
while not stack.is_empty():
    print(stack.pop())
# Out:
# world!
# Hello,
